# %% [markdown]
# ### Testing & developing ...

# %%
import thomas.core
from thomas.core import get_pkg_filename
from thomas.core import BayesianNetwork, examples
from thomas.jupyter import BayesianNetworkWidget

# %%
Gs = examples.get_student_network()

# %%
view = BayesianNetworkWidget(Gs)
view
# Out:
# BayesianNetworkWidget(marginals_and_evidence={'marginals': {'I': {'i0': 0.7, 'i1': 0.3}, 'S': {'s0': 0.725, 's…

# %%
Gs.set_evidence_hard('I', 'i1')

# %%
Gs.set_evidence_hard('D', 'd1')

# %%
Gs.reset_evidence()

# %%
Gs.nodes
# Out:
# {'I': DiscreteNetworkNode('I', name='I', states=['i0', 'i1'], description='Intelligence'),
#  'S': DiscreteNetworkNode('S', name='S', states=['s0', 's1'], description='SAT Score'),
#  'D': DiscreteNetworkNode('D', name='D', states=['d0', 'd1'], description='Difficulty'),
#  'G': DiscreteNetworkNode('G', name='G', states=['g1', 'g2', 'g3'], description='Grade'),
#  'L': DiscreteNetworkNode('L', name='L', states=['l0', 'l1'], description='Letter')}

# %%
Gs.get_marginals()
# Out:
# {'I': factor(I)
#  I
#  i0    0.7
#  i1    0.3
#  dtype: float64,
#  'S': factor(S)
#  S
#  s0    0.725
#  s1    0.275
#  dtype: float64,
#  'D': factor(D)
#  D
#  d0    0.6
#  d1    0.4
#  dtype: float64,
#  'G': factor(G)
#  G
#  g1    0.362
#  g2    0.288
#  g3    0.350
#  dtype: float64,
#  'L': factor(L)
#  L
#  l0    0.498
#  l1    0.502
#  dtype: float64}
